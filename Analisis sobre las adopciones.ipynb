# %% [markdown]
# # Adopciones
#
#
# # Objetivo: analizar el censo realizado en el 2020 sobre la edad, especie y sexo de los animales que terminan en el refugio King County (EEUU) para ser adoptados
#
#
# 1. ¿Cuantos animales son adoptados en 1 año, cuantos encontrados por sus dueños y cuantos estaban perdidos?
# 2. ¿Que tipo de animales terminan en refugios? ¿En su mayoría son perros o gatos?
# 3. ¿Qué cantidad de machos y cuantas hembras ingresan?
# 4. ¿Que rango de edad tienen los animales ingresantes?
#
#
#
# ## Indice
# 1. Carga de datos
# 2. Exploracion
# 3. Limpieza de datos
# 4. Presentacion de datos
# 5. Conclusion
#
# ## Paginas Web
# 1. https://data.world/kingcounty/yaai-7frk/workspace/file?filename=lost-found-adoptable-pets-1.csv
# 2. https://kingcounty.gov/depts/regional-animal-services.aspx

# %% [markdown]
# ## 1.Carga de datos

# %%
import pandas as pd

# %%
pd.read_csv("dogs.csv")
# Out:
#      impound_no Animal_ID                              Data_Source  \
# 0    K22-143343   A656261  Regional Animal Services of King County
# 1    K22-143932   A657702  Regional Animal Services of King County
# 2    K22-143814   A657367  Regional Animal Services of King County
# 3    K22-144091   A658207  Regional Animal Services of King County
# 4    K22-143816   A657372  Regional Animal Services of King County
# ..          ...       ...                                      ...
# 315  K22-143316   A656182  Regional Animal Services of King County
# 316  K22-143635   A656977  Regional Animal Services of King County
# 317  K22-143360   A656297  Regional Animal Services of King County
# 318  K22-143936   A657725  Regional Animal Services of King County
# 319  K22-144009   A657901  Regional Animal Services of King County
#
#     Record_Type                                               Link  \
# 0         FOUND  https://petharbor.com/PublicDetail.asp?searcht...
# ...

# %%
df = pd.read_csv("dogs.csv")

# %% [markdown]
# # 2. Exploracion

# %%
df.head()
# Out:
#    impound_no Animal_ID                              Data_Source Record_Type  \
# 0  K22-143343   A656261  Regional Animal Services of King County       FOUND
# 1  K22-143932   A657702  Regional Animal Services of King County   ADOPTABLE
# 2  K22-143814   A657367  Regional Animal Services of King County        LOST
# 3  K22-144091   A658207  Regional Animal Services of King County        LOST
# 4  K22-143816   A657372  Regional Animal Services of King County       FOUND
#
#                                                 Link  \
# 0  https://petharbor.com/PublicDetail.asp?searcht...
# 1    https://petharbor.com/pet.asp?uaid=KING.A657702
# 2  https://petharbor.com/PublicDetail.asp?searcht...
# 3  https://petharbor.com/PublicDetail.asp?searcht...
# 4  https://kingcounty.gov/depts/regional-animal-s...
#
#                                     Current_Location   Animal_Name  \
# 0                                     In Public Home  Jennifer Lun
# ...

# %%
df ["animal_type"]
# Out:
# 0           Dog
# 1           Dog
# 2           Cat
# 3           Dog
# 4      Dead Cat
#          ...
# 315         Dog
# 316         Cat
# 317         Cat
# 318         Rat
# 319         Cat
# Name: animal_type, Length: 320, dtype: object

# %%
df["Age"]
# Out:
# 0       Over 1 year<p/>
# 1       1 YEAR 8 MONTHS
# 2       Over 1 year<p/>
# 3       Over 1 year<p/>
# 4                NO AGE
#              ...
# 315         Unknown<p/>
# 316    Under 1 year<p/>
# 317     Over 1 year<p/>
# 318              NO AGE
# 319    Under 1 year<p/>
# Name: Age, Length: 320, dtype: object

# %%
df["Animal_Gender"]
# Out:
# 0               Male
# 1      Neutered Male
# 2               Male
# 3            Unknown
# 4            Unknown
#            ...
# 315             Male
# 316             Male
# 317             Male
# 318           Female
# 319             Male
# Name: Animal_Gender, Length: 320, dtype: object

# %%
df["Record_Type"]
# Out:
# 0          FOUND
# 1      ADOPTABLE
# 2           LOST
# 3           LOST
# 4          FOUND
#          ...
# 315        FOUND
# 316         LOST
# 317         LOST
# 318        FOUND
# 319         LOST
# Name: Record_Type, Length: 320, dtype: object

# %% [markdown]
# # 3.Limpieza de datos

# %%
path_info = "dogs.csv"
path_dogs = "dogs.csv"

info = pd.read_csv(path_info)
dogs = pd.read_csv(path_dogs)

# %%
merged = info.merge(ruta, on = ['animal_type', 'Age', 'Animal_Gender' , "Record_Type"])

# %%
merged = merged.drop_duplicates()

# %%
merged[merged.animal_type == 'Dog']
# Out:
#      impound_no_x Animal_ID_x                            Data_Source_x  \
# 0      K22-143343     A656261  Regional Animal Services of King County
# 1      K22-143343     A656261  Regional Animal Services of King County
# 2      K22-143343     A656261  Regional Animal Services of King County
# 3      K22-143343     A656261  Regional Animal Services of King County
# 4      K22-143343     A656261  Regional Animal Services of King County
# ...           ...         ...                                      ...
# 5874   K22-144037     A630220  Regional Animal Services of King County
# 5880   K22-143330     A626473  Regional Animal Services of King County
# 5881   K22-144015     A657955  Regional Animal Services of King County
# 5882   K22-144069     A658164  Regional Animal Services of King County
# 5888   K22-144036     A658039  Regional Animal Services of King County
#
#      Record_Type_x                                             Link_x  \
# ...

# %%
merged[merged.animal_type == 'Cat']
# Out:
#      impound_no_x Animal_ID_x                            Data_Source_x  \
# 2210   K22-143814     A657367  Regional Animal Services of King County
# 2211   K22-143814     A657367  Regional Animal Services of King County
# 2212   K22-143814     A657367  Regional Animal Services of King County
# 2213   K22-143814     A657367  Regional Animal Services of King County
# 2214   K22-143814     A657367  Regional Animal Services of King County
# ...           ...         ...                                      ...
# 5877   K22-143961     A657797  Regional Animal Services of King County
# 5878   K22-143961     A657797  Regional Animal Services of King County
# 5879   K21-142440     A640100  Regional Animal Services of King County
# 5887   K22-143570     A655325  Regional Animal Services of King County
# 5889   K21-141937     A653196  Regional Animal Services of King County
#
#      Record_Type_x                                             Link_x  \
# ...

# %%
merged[merged.Animal_Gender == 'Female']
# Out:
#      impound_no_x Animal_ID_x                            Data_Source_x  \
# 3464   K22-143910     A657624  Regional Animal Services of King County
# 3465   K22-143910     A657624  Regional Animal Services of King County
# 3466   K22-143910     A657624  Regional Animal Services of King County
# 3467   K22-143910     A657624  Regional Animal Services of King County
# 3468   K22-143910     A657624  Regional Animal Services of King County
# ...           ...         ...                                      ...
# 5848   K22-143512     A430705  Regional Animal Services of King County
# 5851   K22-144095     A658221  Regional Animal Services of King County
# 5858   K22-144040     A658074  Regional Animal Services of King County
# 5872   K21-142797     A655004  Regional Animal Services of King County
# 5882   K22-144069     A658164  Regional Animal Services of King County
#
#      Record_Type_x                                             Link_x  \
# ...

# %%
merged[merged.Animal_Gender == 'Male']
# Out:
#      impound_no_x Animal_ID_x                            Data_Source_x  \
# 0      K22-143343     A656261  Regional Animal Services of King County
# 1      K22-143343     A656261  Regional Animal Services of King County
# 2      K22-143343     A656261  Regional Animal Services of King County
# 4806   K22-143991     A657866  Regional Animal Services of King County
# 4808   K22-143826     A657388  Regional Animal Services of King County
# 4809   K22-144036     A658039  Regional Animal Services of King County
#
#      Record_Type                                             Link_x  \
# ...

# %%
merged[merged.Record_Type == 'LOST']
# Out:
#      impound_no_x Animal_ID_x                            Data_Source_x  \
# 10     K22-143814     A657367  Regional Animal Services of King County
# 11     K22-143814     A657367  Regional Animal Services of King County
# 12     K22-143814     A657367  Regional Animal Services of King County
# 13     K22-143814     A657367  Regional Animal Services of King County
# 14     K22-143814     A657367  Regional Animal Services of King County
# ...           ...         ...                                      ...
# 4708   K22-143365     A656315  Regional Animal Services of King County
# 4709   K22-143365     A656315  Regional Animal Services of King County
# 4710   K22-143365     A656315  Regional Animal Services of King County
# 4767   K22-143498     A656719  Regional Animal Services of King County
# 4786   K21-141398     A651674  Regional Animal Services of King County
#
#      Record_Type                                             Link_x  \
# ...

# %% [markdown]
# # 4. Presentacion de datos

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
Record_Type = [123 , 292 , 4397 ]
tipo = ["Adoptados" , "Encontrados" , "Perdidos"]
colores = ["#F6FD07","#07FD1D" , "#F90B0B"]
defase = (0.1, 0.1, 0.1)
plt.pie(Record_Type, labels=tipo, autopct="%0.1f %%", colors=colores, explode=defase)
plt.title("Animales que ingresan al refugio")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
animal_type = [3429 , 2125 ]
especie = ["Perros" , "Gatos"]
colores = ["#90EE90","#DAA520"]
defase = (0,0.1)
plt.pie(animal_type, labels=especie, autopct="%0.1f %%", colors=colores, explode=defase)
plt.title("Porcentaje entre Perros y Gatos")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Animal_Gender = [1738 , 3940 ]
sexo = ["Hembras" , "Machos"]
colores = ["#ff0080","#00aae4"]
defase = (0,0.1)
plt.pie(Animal_Gender, labels=sexo, autopct="%0.1f %%", colors=colores, explode=defase)
plt.title("Porcentaje entre Hembras y Machos")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Age = [5044 , 311 ]
edad = ["Mas de 1 Año" , "Menos de 1 año"]
colores = ["#EE82EE","#D3D3D3"]
defase = (0,0.1)
plt.pie(animal_type, labels=edad, autopct="%0.1f %%", colors=colores, explode=defase)
plt.title("Porcentaje de edades de los animales que llegan al refugio")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 5. Conclusion

# %% [markdown]
# Con la investigacion realizada se puede determinar que en el año 2020 se registro un ingreso del 91,4%  de animales que estaban perdidos a los distintos refugios de King County distribuidos por Estados Unidos. En este estudio se determina su especie, sexo, edad y por sobre todo cuantos fueron adoptados y cuantos encontrados por sus dueños, ya que el servicio de King County se especializa en volverle a las macostas sus hogares o encontrarles nuevos.
# En el mismo año podemos ver que el 2.6% , alrededor de 123 animales fueron adoptados y el 6,1% ,292 animales, fueron encontrados por sus dueños y el restante 91,4% estaban perdidos terminando asi en los distintos refugios, aun a la espera de ser adoptados.
# En este estudio con todos los animales ingresados podemos ver que la mayoria de ellos son perros, llevandose el 61,7% y el restante son gatos con el 38,3%, tambien se analizo sobre si son machos o hembras, determinando que en su mayoria son machos tanto sean perros o gatos con el 69,4% y hembras con un total de 30,6%.
# Se analizo su edad combinando gatos y perros, ya sean perdidos o adoptados y se pudo determinar que el 61,7% son animales adultos, mayores a 1 año y el 38,3% son menores a 1 año.
# Con este ultimo grafico podemos concluir que los perros o gatos menores a 1 año son rapidamente adoptados por sobre los adultos.
